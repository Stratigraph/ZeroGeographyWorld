# %%
import matplotlib.pyplot as plt

from BatchRunner import BatchRunner

# %%
# %matplotlib inline

# %%
runner = BatchRunner("set_polarity", 5, 1000, large_agents=5, fraction_large=0.7)

# %%
runner.run_all(verbose=False)

# %%
plt.plot(runner.model_outputs[3]["active_agents"])
